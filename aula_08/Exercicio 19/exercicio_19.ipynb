# %% [markdown]
#  # Exercício 19
# ## Análise de Pinguins e História dos Oceanos Dataset do Kaggle: Palmer's Penguins
#
# https://www.kaggle.com/datasets/samybaladram/palmers-penguin-dataset-extended
#
# ### O dataset de Palmer's Penguins contém informações sobre três espécies de pinguins, suas características físicas e o ambiente onde vivem. Imagine que você está trabalhando para um documentário sobre as mudanças climáticas e deseja usar os dados dos pinguins para contar uma história visual sobre como essas mudanças estão afetando essas aves marinhas.

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataset_penguins = pd.read_csv('palmerpenguins_extended.csv')
dataset_penguins
# Out:
# Matplotlib is building the font cache; this may take a moment.
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0     Adelie  Biscoe            53.4           17.8              219.0
# 1     Adelie  Biscoe            49.3           18.1              245.0
# 2     Adelie  Biscoe            55.7           16.6              226.0
# 3     Adelie  Biscoe            38.0           15.6              221.0
# 4     Adelie  Biscoe            60.7           17.9              177.0
# ...      ...     ...             ...            ...                ...
# 3425  Gentoo  Biscoe            44.0           20.4              252.0
# 3426  Gentoo  Biscoe            54.5           25.2              245.0
# 3427  Gentoo  Biscoe            51.4           20.4              258.0
# 3428  Gentoo  Biscoe            55.9           20.5              247.0
# 3429  Gentoo  Biscoe            43.9           22.9              206.0
#
# ...

# %% [markdown]
# ## Tarefas
#
# ### • Existem valores ausentes ou inconsistentes no dataset? Se sim, como você trataria esses dados para garantir a qualidade da análise?

# %%
valores_ausentes = dataset_penguins.isnull().sum()
valores_ausentes
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# diet                 0
# life_stage           0
# health_metrics       0
# year                 0
# dtype: int64

# %% [raw]
# Não existem valores ausentes, mas se fosse o caso, preencheria com um valor pré definido.

# %% [markdown]
# ### • Realize uma análise exploratória dos dados para entender as características físicas (como peso, comprimento do bico e comprimento da asa) das três espécies de pinguins. Utilize agregações e agrupamentos para comparar essas características entre as espécies.

# %%
dataset_penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm   body_mass_g  \
# count     3430.000000    3430.000000        3430.000000   3430.000000
# mean        38.529825      18.447143         207.028863   4834.710496
# std         13.175171       2.774428          28.944765   1311.091310
# min         13.600000       9.100000         140.000000   2477.000000
# 25%         28.900000      16.600000         185.000000   3843.500000
# 50%         34.500000      18.400000         203.000000   4633.500000
# 75%         46.600000      20.300000         226.000000   5622.000000
# max         88.200000      27.900000         308.000000  10549.000000
#
#               year
# count  3430.000000
# mean   2023.348397
# std       1.313797
# min    2021.000000
# 25%    2022.000000
# 50%    2024.000000
# 75%    2024.000000
# max    2025.000000

# %%
# Selecionar apenas as colunas numéricas para calcular a média
numeric_columns = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
mean_values = dataset_penguins.groupby('species')[numeric_columns].mean()
mean_values
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          35.431603      17.464487         200.759615  4445.475641
# Chinstrap       35.014607      18.421188         201.675762  4602.531300
# Gentoo          44.161909      19.689415         217.546111  5437.640738

# %%
import plotly.express as px

# Gráfico de boxplot para comparar o peso corporal entre as espécies
fig_weight = px.box(dataset_penguins, x='species', y='body_mass_g', title='Distribuição do Peso Corporal por Espécie')
fig_weight.show()

# %%
# Gráfico de boxplot para comparar o comprimento do bico entre as espécies
fig_bill_length = px.box(dataset_penguins, x='species', y='bill_length_mm', title='Distribuição do Comprimento do Bico por Espécie')
fig_bill_length.show()

# %%
# Gráfico de boxplot para comparar o comprimento da asa entre as espécies
fig_flipper_length = px.box(dataset_penguins, x='species', y='flipper_length_mm', title='Distribuição do Comprimento da Asa por Espécie')
fig_flipper_length.show()

# %% [markdown]
# ### • Crie gráficos para visualizar as diferenças entre as espécies de pinguins com base nas características físicas. Use gráficos de dispersão, boxplot e histogramas para mostrar as distribuições e comparações entre as variáveis.

# %%
# Gráfico de dispersão para comprimento do bico vs. profundidade do bico
fig_scatter_bill = px.scatter(dataset_penguins, x='bill_length_mm', y='bill_depth_mm', color='species',
                              title='Comprimento do Bico vs. Profundidade do Bico')
fig_scatter_bill.show()

# %%
# Gráfico de dispersão para comprimento da asa vs. peso corporal
fig_scatter_flipper = px.scatter(dataset_penguins, x='flipper_length_mm', y='body_mass_g', color='species',
                                 title='Comprimento da Asa vs. Peso Corporal')
fig_scatter_flipper.show()

# %%
# Gráfico de boxplot para comparar o peso corporal entre as espécies
fig_box_weight = px.box(dataset_penguins, x='species', y='body_mass_g', title='Distribuição do Peso Corporal por Espécie')
fig_box_weight.show()

# %%
# Gráfico de boxplot para comparar o comprimento do bico entre as espécies
fig_box_bill_length = px.box(dataset_penguins, x='species', y='bill_length_mm', title='Distribuição do Comprimento do Bico por Espécie')
fig_box_bill_length.show()

# %%
# Gráfico de boxplot para comparar o comprimento da asa entre as espécies
fig_box_flipper_length = px.box(dataset_penguins, x='species', y='flipper_length_mm', title='Distribuição do Comprimento da Asa por Espécie')
fig_box_flipper_length.show()

# %%
# Histograma para o comprimento do bico
fig_hist_bill_length = px.histogram(dataset_penguins, x='bill_length_mm', color='species', barmode='overlay',
                                    title='Distribuição do Comprimento do Bico por Espécie')
fig_hist_bill_length.show()

# %%
# Histograma para o comprimento da asa
fig_hist_flipper_length = px.histogram(dataset_penguins, x='flipper_length_mm', color='species', barmode='overlay',
                                       title='Distribuição do Comprimento da Asa por Espécie')

fig_hist_flipper_length.show()

# %%
# Histograma para o peso corporal
fig_hist_weight = px.histogram(dataset_penguins, x='body_mass_g', color='species', barmode='overlay',
                               title='Distribuição do Peso Corporal por Espécie')
fig_hist_weight.show()

# %% [markdown]
# ### • Com base nas suas visualizações, escreva uma breve narrativa que conecte os dados com a situação atual dos pinguins. O que os dados sugerem sobre o habitat e as condições físicas desses animais? Como isso pode ser interpretado em relação às mudanças ambientais?

# %% [markdown]
# # Storytelling:
#
# Os dados dos pinguins de Palmer revelam informações valiosas sobre as características físicas e o habitat dessas aves marinhas. Ao analisar as distribuições de peso, comprimento do bico e comprimento da asa entre as três espécies de pinguins (Adélie, Gentoo e Chinstrap), podemos observar algumas tendências importantes.
#
# # Características Físicas e Habitat
# ## Peso Corporal:
# Os gráficos de boxplot mostram que os pinguins Gentoo tendem a ser mais pesados em comparação com as espécies Adélie e Chinstrap. Isso pode indicar que os Gentoo têm acesso a recursos alimentares mais abundantes ou de maior qualidade em seu habitat.
# ## Comprimento do Bico e da Asa:
# As distribuições do comprimento do bico e da asa variam entre as espécies, com os pinguins Gentoo apresentando bicos e asas mais longos. Essas diferenças podem estar relacionadas às adaptações específicas de cada espécie ao seu ambiente e dieta.
# ## Distribuição Geográfica:
# A análise dos dados geográficos sugere que as diferentes espécies de pinguins ocupam nichos ecológicos distintos nas ilhas de Palmer. As variações nas características físicas podem refletir adaptações evolutivas às condições ambientais específicas de cada ilha.
# ## Impacto das Mudanças Climáticas
# As mudanças climáticas estão afetando os habitats dos pinguins de várias maneiras:
#
# ## Disponibilidade de Alimentos:
# O aquecimento dos oceanos e a redução do gelo marinho podem impactar a disponibilidade de krill, um alimento essencial para os pinguins. Isso pode explicar as variações no peso corporal observadas entre as espécies, com algumas espécies sendo mais afetadas pela escassez de alimentos.
# ## Mudanças no Habitat:
# A perda de gelo marinho e as mudanças na cobertura de neve podem alterar os locais de nidificação e reprodução dos pinguins. Espécies que dependem de gelo marinho, como os pinguins Adélie, podem enfrentar desafios maiores em comparação com espécies mais adaptáveis, como os Gentoo.
# ## Saúde e Sobrevivência:
# As mudanças nas condições ambientais podem afetar a saúde e a sobrevivência dos pinguins. A análise dos dados de saúde e dieta pode revelar correlações entre a saúde dos pinguins e as mudanças no ambiente, destacando a importância de monitorar essas populações para entender os impactos a longo prazo.\
# Os dados dos pinguins de Palmer fornecem uma visão detalhada das características físicas e do habitat dessas aves, permitindo-nos entender melhor como as mudanças climáticas estão afetando suas vidas. As variações observadas nas características físicas e na distribuição geográfica sugerem que os pinguins estão enfrentando desafios significativos devido às mudanças ambientais. Monitorar essas populações e continuar a pesquisa é crucial para desenvolver estratégias de conservação eficazes e proteger essas espécies vulneráveis.
