# %% [markdown]
# # Exercício 20
#
# ## Análise de Consumo de Energia e Emissões de CO2
# Dataset do Kaggle: World Energy Consumption
# https://www.kaggle.com/datasets/pralabhpoudel/world-energy-consumption
# ### Faça um join entre os dados de consumo de energia e emissões de CO2 por país/continente.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


consumo_energia_mundial = pd.read_csv('world_energy_consumption.csv')
consumo_energia_mundial
# Out:
#              country  year iso_code  population           gdp  \
# 0      ASEAN (Ember)  2000      NaN         NaN           NaN
# 1      ASEAN (Ember)  2001      NaN         NaN           NaN
# 2      ASEAN (Ember)  2002      NaN         NaN           NaN
# 3      ASEAN (Ember)  2003      NaN         NaN           NaN
# 4      ASEAN (Ember)  2004      NaN         NaN           NaN
# ...              ...   ...      ...         ...           ...
# 22007       Zimbabwe  2018      ZWE  15052191.0  2.271535e+10
# 22008       Zimbabwe  2019      ZWE  15354606.0           NaN
# 22009       Zimbabwe  2020      ZWE  15669663.0           NaN
# 22010       Zimbabwe  2021      ZWE  15993525.0           NaN
# 22011       Zimbabwe  2022      ZWE  16320539.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# ...

# %%
# Limpeza do Dataset

consumo_energia_mundial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22012 entries, 0 to 22011
# Columns: 129 entries, country to wind_share_energy
# dtypes: float64(126), int64(1), object(2)
# memory usage: 21.7+ MB

# %%
consumo_energia_mundial.describe()
# Out:
#                year    population           gdp  biofuel_cons_change_pct  \
# count  22012.000000  1.812300e+04  1.111300e+04              1747.000000
# mean    1974.213247  1.053096e+08  3.585114e+11                46.091694
# std       35.058653  4.640460e+08  2.411179e+12               274.616745
# min     1900.000000  1.833000e+03  1.642060e+08              -100.000000
# 25%     1946.000000  1.712404e+06  1.365898e+10                -0.616500
# 50%     1984.000000  6.991543e+06  4.167411e+10                 8.179000
# 75%     2003.000000  2.557688e+07  1.744295e+11                26.508500
# max     2022.000000  7.975105e+09  1.136302e+14              5659.328000
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# count              2687.000000              2302.000000          2767.000000
# mean                  2.719074               133.558459            38.068209
# std                  10.057018               264.707851           111.623148
# ...

# %%
consumo_energia_mundial.isnull().sum()
# Out:
# country                       0
# year                          0
# iso_code                   5500
# population                 3889
# gdp                       10899
#                           ...
# wind_elec_per_capita      14947
# wind_electricity          14016
# wind_energy_per_capita    17947
# wind_share_elec           15126
# wind_share_energy         17911
# Length: 129, dtype: int64

# %%
consumo_energia_mundial.dropna()
# Out:
#              country  year iso_code   population           gdp  \
# 1071       Argentina  2011      ARG   41520736.0  8.359705e+11
# 1072       Argentina  2012      ARG   41952364.0  8.274048e+11
# 1073       Argentina  2013      ARG   42388268.0  8.473051e+11
# 1074       Argentina  2014      ARG   42824064.0  8.259815e+11
# 1075       Argentina  2015      ARG   43257064.0  8.478550e+11
# ...              ...   ...      ...          ...           ...
# 20702  United States  2014      USA  322033952.0  1.648266e+13
# 20703  United States  2015      USA  324607776.0  1.690258e+13
# 20704  United States  2016      USA  327210208.0  1.716256e+13
# 20705  United States  2017      USA  329791232.0  1.759628e+13
# 20706  United States  2018      USA  332140032.0  1.814065e+13
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 1071                    46.423                    2.750
# 1072                    19.876                    1.724
# ...

# %% [markdown]
# Dataset do Kaggle: Countries CO2 Emission and more... https://www.kaggle.com/datasets/lobosi/c02-emission-by-countrys-grouth-and-population

# %%
co2_emission = pd.read_csv('energy.csv')
co2_emission
# Out:
#        Unnamed: 0   Country                Energy_type  Year  \
# 0               0     World           all_energy_types  1980
# 1               1     World                       coal  1980
# 2               2     World                natural_gas  1980
# 3               3     World  petroleum_n_other_liquids  1980
# 4               4     World                    nuclear  1980
# ...           ...       ...                        ...   ...
# 55435       55435  Zimbabwe                       coal  2019
# 55436       55436  Zimbabwe                natural_gas  2019
# 55437       55437  Zimbabwe  petroleum_n_other_liquids  2019
# 55438       55438  Zimbabwe                    nuclear  2019
# 55439       55439  Zimbabwe         renewables_n_other  2019
#
#        Energy_consumption  Energy_production           GDP    Population  \
# 0              292.899790         296.337228  27770.910281  4.298127e+06
# 1               78.656134          80.114194  27770.910281  4.298127e+06
# ...

# %%
co2_emission.dropna()
# Out:
#        Unnamed: 0   Country                Energy_type  Year  \
# 0               0     World           all_energy_types  1980
# 1               1     World                       coal  1980
# 2               2     World                natural_gas  1980
# 3               3     World  petroleum_n_other_liquids  1980
# 4               4     World                    nuclear  1980
# ...           ...       ...                        ...   ...
# 55434       55434  Zimbabwe           all_energy_types  2019
# 55435       55435  Zimbabwe                       coal  2019
# 55436       55436  Zimbabwe                natural_gas  2019
# 55437       55437  Zimbabwe  petroleum_n_other_liquids  2019
# 55439       55439  Zimbabwe         renewables_n_other  2019
#
#        Energy_consumption  Energy_production           GDP    Population  \
# 0              292.899790         296.337228  27770.910281  4.298127e+06
# 1               78.656134          80.114194  27770.910281  4.298127e+06
# ...

# %%
df_emissao_co2 = pd.merge(consumo_energia_mundial, co2_emission, left_on='country', right_on='Country', how='inner' )
df_emissao_co2
# Out:
#              country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0        Afghanistan  1900      AFG   4707744.0  NaN                      NaN
# 1        Afghanistan  1900      AFG   4707744.0  NaN                      NaN
# 2        Afghanistan  1900      AFG   4707744.0  NaN                      NaN
# 3        Afghanistan  1900      AFG   4707744.0  NaN                      NaN
# 4        Afghanistan  1900      AFG   4707744.0  NaN                      NaN
# ...              ...   ...      ...         ...  ...                      ...
# 3785275     Zimbabwe  2022      ZWE  16320539.0  NaN                      NaN
# 3785276     Zimbabwe  2022      ZWE  16320539.0  NaN                      NaN
# 3785277     Zimbabwe  2022      ZWE  16320539.0  NaN                      NaN
# 3785278     Zimbabwe  2022      ZWE  16320539.0  NaN                      NaN
# 3785279     Zimbabwe  2022      ZWE  16320539.0  NaN                      NaN
#
# ...

# %% [markdown]
# ## • Crie um Boxplot que compare o consumo de energias renováveis e fósseis por continente.

# %% [markdown]
# ## • Use gráficos de linha para mostrar a evolução do consumo de energias renováveis e fósseis e as emissões de CO2 ao longo do tempo.

# %% [markdown]
# ## • Visualize a contribuição dos setores (indústria, transporte, etc.) para as emissões de CO2 por continente.

# %% [markdown]
# ## • Crie gráficos de dispersão para analisar a correlação entre o consumo de energia fóssil e as emissões de CO2 por continente, incluindo uma linha de regressão.

# %% [markdown]
# ## • Crie gráficos interativos que permitam visualizar como o consumo energético impacta as emissões ao longo do tempo em diferentes regiões.

# %% [markdown]
# ## Explique como o consumo de energia está relacionado às emissões de CO2, destacando diferenças regionais e setoriais.
